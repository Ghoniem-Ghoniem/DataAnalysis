# %%
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sb
import pyodbc 
import pandas as pd

# %%
##Connecting to sql database
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=.;'
                      'Database=mldatabase;'
                      'Trusted_Connection=yes;')

cursor = conn.cursor()
query= 'SELECT * FROM groups'
cursor.execute(query)
for i in cursor:
    print(i)
# Out:
# ('أسماء الإشارة', None, None)
# ('أعلام', None, None)
# ('أماكن', None, None)
# ('إن وأخواتها', None, None)
# ('أنهار', None, None)
# ('الأسماء الخمسة', None, None)
# ('الأسماء الموصولة', None, None)
# ('الطعام', None, None)
# ('بحار', None, None)
# ('حروف الاستفتاح', None, None)
# ('حروف الاستفهام', None, None)
# ('حروف التفسير', None, None)
# ('حروف الجر', None, None)
# ('حروف الجزم', None, None)
# ('حروف الشرط', None, None)
# ('حروف العطف', None, None)
# ('حروف القسم', None, None)
# ('حروف النصب', None, None)
# ('حروف النفي', None, None)
# ('حروف الهجاء', None, None)
# ('حيوانات', None, None)
# ('كان وأخواتها', None, None)
# ('محافظات', None, None)
# ('معالم سياحية', None, None)
# ('ملابس', None, None)
# ('مناسبات', None, None)
# ('مناطق مشهورة', None, None)
# ('نباتات', None, None)

# %%
SQLdf = pd.read_sql(query, conn)
SQLdf
# Out:
#              GroupID GroupArabicName GroupEnglishName
# 0      أسماء الإشارة            None             None
# 1              أعلام            None             None
# 2              أماكن            None             None
# 3        إن وأخواتها            None             None
# 4              أنهار            None             None
# 5     الأسماء الخمسة            None             None
# 6   الأسماء الموصولة            None             None
# 7             الطعام            None             None
# 8               بحار            None             None
# 9     حروف الاستفتاح            None             None
# 10    حروف الاستفهام            None             None
# 11      حروف التفسير            None             None
# 12         حروف الجر            None             None
# 13        حروف الجزم            None             None
# 14        حروف الشرط            None             None
# 15        حروف العطف            None             None
# ...

# %% [markdown]
# # Matplotlib Liberary Visualization Samples

# %%
groupeddf = SQLdf.groupby("GroupID").count()
groupeddf
# Out:
#                   GroupArabicName  GroupEnglishName
# GroupID
# أسماء الإشارة                   0                 0
# أعلام                           0                 0
# أماكن                           0                 0
# أنهار                           0                 0
# إن وأخواتها                     0                 0
# الأسماء الخمسة                  0                 0
# الأسماء الموصولة                0                 0
# الطعام                          0                 0
# بحار                            0                 0
# حروف الاستفتاح                  0                 0
# حروف الاستفهام                  0                 0
# حروف التفسير                    0                 0
# حروف الجر                       0                 0
# حروف الجزم                      0                 0
# حروف الشرط                      0                 0
# حروف العطف                      0                 0
# حروف القسم                      0                 0
# ...

# %%
table = pd.pivot_table(data=df,index=['Year'],aggfunc='mean')
X = table.index #index represents the years
Y = table["Revenue"] # the grouped value of the revenue

# %%
#formating the graph 
plt.xlabel("Year")
plt.ylabel("Revenue")
plt.title("Revenue per year");
plt.legend()
ax = plt.bar(X,Y)
def Change_labels(X,Y):
    for i in range(len(X)):
        plt.text(i,Y[i],Y[i],transform=ax.transAxes)
#Change_labels(X,Y)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.bar(X,Y,label="Revenue")
plt.bar(X,Y*.25,label="Profit") #We can get it from another column, to represent multi bar column
plt.legend(loc="best")
plt.show()

# %%
#Make bars beside each others to compare
plt.bar(X- 0.2,Y,width=.3 ,label="Revenue")
plt.bar(X+ 0.2,Y*.25,width=.3,label="Profit") #We can get it from another column, to represent multi bar column
plt.legend(loc="best")
plt.show()

# %%
plt.barh(X,Y) #Horizontal bar
plt.show()

# %%
plt.scatter(X,Y) #scatter plot
plt.show()

# %%
plt.scatter(df.Year,df.Revenue) #scatter plot
plt.show()

# %%
plt.boxplot(Y)
plt.show()

# %%
plt.boxplot(df.Revenue)
plt.xlabel('Revenue Per Month')
plt.show()

# %%
red_square = dict(markerfacecolor='r', marker='s')
plt.boxplot(Y,vert=False,flierprops=red_square,showmeans=True)
plt.show()

# %%
plt.pie(Y,labels=X,shadow=False,autopct='%.2f%%') #pie plot
plt.show()

# %%
plt.plot(Y) #Line ploting
plt.show()

# %%
#Ability to show multi data at the same model, that can be used in comparisons with showing the legend for each
plt.plot(OriginalDF.Revenue,label="Revenue")
plt.plot(OriginalDF.Bank_Balance,label="Bank Balance")
plt.legend(loc="best")
plt.show()

# %%
#Ability to show multi data at the same model, that can be used in comparisons with showing the legend for each
plt.plot(OriginalDF.Revenue,'bo', label="Revenue")#blue O
plt.plot(OriginalDF.Bank_Balance,'ro',label="Bank Balance") #Red O
plt.legend(loc="best")
plt.show()

# %% [markdown]
# plt.imshow(groupeddf) #scatter plot
# plt.show()

# %% [markdown]
# # Seaborn Liberary Visualization Samples

# %%
#Seaborn data visualization
sb.barplot(X,Y)

# %%
#Seaborn data visualization
sb.distplot(X,kde=True,bins=5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#Seaborn data visualization
sb.distplot(Y,kde=False,bins=3)

# %%
#Seaborn data visualization
sb.boxenplot(Y)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
sb.boxplot(Y)

# %%
sb.swarmplot(X, Y, color=".25")

# %%
#Seaborn data visualization
sb.scatterplot(X,Y)

# %%
#Seaborn data visualization
sb.lineplot(X,Y)

# %%
#Seaborn data visualization
sb.scatterplot(X,Y)

# %%
#Seaborn data visualization for normal distribution
sb.distplot(Y,rug=True,hist=False)

# %%
#Seaborn data visualization for regression
sb.regplot(x=X,y=Y,color="g")

# %%
#Seaborn data visualization for heatmap
sb.heatmap(table,annot=True, fmt=" ")

# %%
#Seaborn data visualization for heatmap
OriginalDF['Month']=OriginalDF['Month'].str.replace("22","") 
OriginalDF['Month']=OriginalDF['Month'].str.replace("23","")
OriginalDF['Month']=OriginalDF['Month'].str.replace("24","") 
OriginalDF['Month']=OriginalDF['Month'].str.replace("25","") 
Heatmapdf =OriginalDF.pivot_table(values='Revenue',index='Month',columns='Year')

AX =sb.heatmap(Heatmapdf,cmap=sb.cm.rocket_r) # default cmap=sb.cm.rocket, we change it to get the higher value with dark color 
#AX.invert_yaxis()
Heatmapdf
#sb.clustermap(Heatmapdf) to be tested to dected clustered maps
# Out:
# Year        2022     2023     2024     2025
# Month
# أغسطس    39000.0  40000.0  40000.0      NaN
# أكتوبر   80000.0  80000.0  82000.0      NaN
# إبريل    39000.0  39000.0  40000.0      NaN
# ديسمبر   41000.0  45000.0  45000.0      NaN
# سبتمبر   50000.0  50000.0  50000.0      NaN
# فبراير       NaN  50000.0  50000.0  45000.0
# مارس     30000.0  33000.0  33000.0      NaN
# مايو     41000.0  36000.0  40000.0      NaN
# نوفمبر   39000.0  45000.0  45000.0      NaN
# يناير        NaN  30000.0  30000.0  45000.0
# يوليو    43000.0  36000.0  40000.0      NaN
# يونيو    39000.0  36000.0  40000.0      NaN

# %%
sb.pairplot(df,hue='Year',palette='coolwarm',diag_kind="kde") #the same for dist

# %%
sb.pairplot(df,hue='Year',palette='coolwarm',diag_kind="Hist") #the same for dist
