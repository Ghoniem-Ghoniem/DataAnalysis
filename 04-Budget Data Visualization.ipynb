# %%
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd

# %%
#Rading the datasets
OriginalDF = pd.read_excel("Budget.xlsx",'01-Budget')
MainFile =OriginalDF[["Year","Balance","Revenue","Home_Expenses"]].head(36)
df = OriginalDF[["Year","Revenue"]].head(36) #Keep the dataset origniality
df
# Out:
#     Year  Revenue
# 0   2022  30000.0
# 1   2022  39000.0
# 2   2022  41000.0
# 3   2022  39000.0
# 4   2022  43000.0
# 5   2022  39000.0
# 6   2022  50000.0
# 7   2022  80000.0
# 8   2022  39000.0
# 9   2022  41000.0
# 10  2023  30000.0
# 11  2023  50000.0
# 12  2023  33000.0
# 13  2023  39000.0
# 14  2023  36000.0
# 15  2023  36000.0
# 16  2023  36000.0
# 17  2023  40000.0
# 18  2023  50000.0
# 19  2023  80000.0
# 20  2023  45000.0
# 21  2023  45000.0
# 22  2024  30000.0
# 23  2024  50000.0
# 24  2024  33000.0
# 25  2024  40000.0
# 26  2024  40000.0
# 27  2024  40000.0
# 28  2024  40000.0
# 29  2024  40000.0
# 30  2024  50000.0
# 31  2024  82000.0
# 32  2024  45000.0
# 33  2024  45000.0
# 34  2025  45000.0
# 35  2025  45000.0

# %%
#Sample of data preparation
df.Revenue.fillna(df.Revenue.median(), inplace=True)
df
# Out:
#     Year  Revenue
# 0   2022  30000.0
# 1   2022  39000.0
# 2   2022  41000.0
# 3   2022  39000.0
# 4   2022  43000.0
# 5   2022  39000.0
# 6   2022  50000.0
# 7   2022  80000.0
# 8   2022  39000.0
# 9   2022  41000.0
# 10  2023  30000.0
# 11  2023  50000.0
# 12  2023  33000.0
# 13  2023  39000.0
# 14  2023  36000.0
# 15  2023  36000.0
# 16  2023  36000.0
# 17  2023  40000.0
# 18  2023  50000.0
# 19  2023  80000.0
# 20  2023  45000.0
# 21  2023  45000.0
# 22  2024  30000.0
# 23  2024  50000.0
# 24  2024  33000.0
# 25  2024  40000.0
# 26  2024  40000.0
# 27  2024  40000.0
# 28  2024  40000.0
# 29  2024  40000.0
# 30  2024  50000.0
# 31  2024  82000.0
# 32  2024  45000.0
# 33  2024  45000.0
# 34  2025  45000.0
# 35  2025  45000.0

# %% [markdown]
# # Matplotlib Liberary Visualization Samples

# %%
#Data Summarization using group by
groupeddf = df.groupby("Year").sum()
groupeddf
# Out:
#        Revenue
# Year
# 2022  441000.0
# 2023  520000.0
# 2024  535000.0
# 2025   90000.0

# %%
#Data Summarization using pivot table
table = pd.pivot_table(data=df,index=['Year'],aggfunc='mean')
print (table)
X = table.index #index represents the years
Y = table["Revenue"] # the grouped value of the revenue
# Out:
#            Revenue
# Year
# 2022  44100.000000
# 2023  43333.333333
# 2024  44583.333333
# 2025  45000.000000

# %%
#We are ready now for data visualization
#formating the graph 
# setting figure size by using figure() function 
plt.figure(figsize=[6,6])
plt.title("Revenue per year");
plt.xlabel("Year")
plt.ylabel("Revenue")
plt.bar(X,Y)
ax = plt.show()

# %%
#Plottig multi bars at the same figure
NetProfit = Y *.30 
plt.title("Revenue Vs Profit per year");
plt.bar(X,Y,label="Revenue")
plt.bar(X,NetProfit,label="Profit") #We can get it from another column, to represent multi bar column
plt.legend(loc="best")
plt.show()

# %%
#Make bars beside each others to compare
plt.bar(X- 0.2,Y,width=.3 ,label="Revenue")
plt.bar(X+ 0.2,Y*.25,width=.3,label="Profit") #We can get it from another column, to represent multi bar column
plt.legend(loc="best")
plt.show()

# %%
plt.barh(X,Y) #Horizontal bar
plt.show()

# %%
plt.scatter(df.Year,df.Revenue) #scatter plot using direct attributes
plt.show()

# %%
plt.scatter("Year","Revenue",data = df) #scatter plot using data set
plt.show()

# %%
plt.scatter(df.Year,df.Revenue) #scatter plot with different attributes
plt.scatter(OriginalDF.Year,OriginalDF.Bank_Balance) #scatter plot
plt.legend(numpoints=1)
plt.show()

# %%
plt.boxplot(df.Revenue)
plt.show()

# %%
ax= plt.subplot()
ax.boxplot(df.Revenue)
plt.xlabel('Revenue Per Month')
plt.show()

# %%
red_square = dict(markerfacecolor='r', marker='s')
plt.boxplot(df.Revenue,vert=False,flierprops=red_square,showmeans=True)
plt.show()

# %%
plt.pie(Y,labels=X,shadow=False,autopct='%.1f%%') #pie plot
plt.show()

# %%
plt.plot(Y) #Line ploting
plt.show()

# %%
#Ability to show multi data at the same model, that can be used in comparisons with showing the legend for each
plt.plot(OriginalDF.Revenue,label="Revenue")
plt.plot(OriginalDF.Bank_Balance,label="Bank Balance")
plt.legend(loc="best")
plt.show()

# %%
#Ability to show multi data at the same model, that can be used in comparisons with showing the legend for each
plt.plot(OriginalDF.Revenue,'bo', label="Revenue")#blue O
plt.plot(OriginalDF.Bank_Balance,'ro',label="Bank Balance") #Red O
plt.legend(loc="best")
plt.show()

# %% [markdown]
# plt.imshow(groupeddf) #scatter plot
# plt.show()

# %% [markdown]
# # Seaborn Liberary Visualization Samples

# %%
#Seaborn data visualization
sb.barplot(X,Y)

# %%
#Seaborn data visualization
sb.distplot(X,kde=True,bins=5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#Seaborn data visualization
sb.distplot(Y,kde=False,bins=3)

# %%
sb.boxplot(OriginalDF.Revenue)

# %%
#Seaborn data visualization
sb.scatterplot(OriginalDF.Revenue,OriginalDF.Year)

# %%
#Seaborn data visualization
sb.lineplot(X,Y)

# %%
#Seaborn data visualization for regression
sb.regplot(x=X,y=Y,color="g")

# %%
#Seaborn data visualization for heatmap
#sb.heatmap(table,annot=True, fmt=".1f",cmap='viridis_r')
sb.heatmap(table,annot=True, fmt=".1f",cmap="rocket_r")

# %%
#Seaborn data visualization for heatmap
OriginalDF['Month']=OriginalDF['Month'].str.replace("22","") 
OriginalDF['Month']=OriginalDF['Month'].str.replace("23","")
OriginalDF['Month']=OriginalDF['Month'].str.replace("24","") 
OriginalDF['Month']=OriginalDF['Month'].str.replace("25","") 
Heatmapdf =OriginalDF.pivot_table(values='Revenue',index='MonthE',columns='Year')

AX =sb.heatmap(Heatmapdf,cmap="Blues") # default cmap=sb.cm.rocket, we change it to get the higher value with dark color 
AX.invert_yaxis()
Heatmapdf
#sb.clustermap(Heatmapdf) to be tested to dected clustered maps
# Out:
# Year          2022     2023     2024     2025
# MonthE
# April      39000.0  39000.0  40000.0      NaN
# August     39000.0  40000.0  40000.0      NaN
# December   41000.0  45000.0  45000.0      NaN
# February       NaN  50000.0  50000.0  45000.0
# January        NaN  30000.0  30000.0  45000.0
# July       43000.0  36000.0  40000.0      NaN
# June       39000.0  36000.0  40000.0      NaN
# March      30000.0  33000.0  33000.0      NaN
# May        41000.0  36000.0  40000.0      NaN
# Novmber    39000.0  45000.0  45000.0      NaN
# October    80000.0  80000.0  82000.0      NaN
# September  50000.0  50000.0  50000.0      NaN

# %%
sb.pairplot(MainFile,hue='Year',palette='coolwarm',diag_kind="auto") #the same for dist

# %%
sb.pairplot(MainFile,hue='Year',palette='coolwarm',diag_kind="Hist") #the same for dist

# %%
sb.pairplot(MainFile,hue='Year',palette='coolwarm',diag_kind="kde") #the same for dist
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
