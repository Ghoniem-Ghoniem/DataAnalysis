# %%
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sb
import pyodbc 
import pandas as pd
import numpy as np
import sklearn as sk

# %%
##Connecting to sql database
# . means the local machine DESKTOP-GVGDMAA
# you can use the machine name or IP 192.168.1.2 , Which will be used in loading data from the cloud
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=192.168.1.2;'
                      'Database=mldatabase;'
                      'Trusted_Connection=yes;')
cursor = conn.cursor()
query= 'SELECT * FROM groups'
cursor.execute(query)
for i in cursor:
    print(i)
# Out:
# ('أسماء الإشارة', None, None, 'اسم')
# ('أعلام', None, None, 'اسم')
# ('أماكن', None, None, 'اسم')
# ('إن وأخواتها', None, None, 'حرف')
# ('أنهار', None, None, 'اسم')
# ('الأسماء الخمسة', None, None, 'اسم')
# ('الأسماء الموصولة', None, None, 'اسم')
# ('الطعام', None, None, 'اسم')
# ('بحار', None, None, 'اسم')
# ('حروف الاستفتاح', None, None, 'حرف')
# ('حروف الاستفهام', None, None, 'حرف')
# ('حروف التفسير', None, None, 'حرف')
# ('حروف الجر', None, None, 'حرف')
# ('حروف الجزم', None, None, 'حرف')
# ('حروف الشرط', None, None, 'حرف')
# ('حروف العطف', None, None, 'حرف')
# ('حروف القسم', None, None, 'حرف')
# ('حروف النصب', None, None, 'حرف')
# ('حروف النفي', None, None, 'حرف')
# ('حروف الهجاء', None, None, 'حرف')
# ('حيوانات', None, None, 'اسم')
# ('كان وأخواتها', None, None, 'فعل')
# ('محافظات', None, None, 'اسم')
# ('معالم سياحية', None, None, 'اسم')
# ('ملابس', None, None, 'اسم')
# ('مناسبات', None, None, 'اسم')
# ('مناطق مشهورة', None, None, 'اسم')
# ('نباتات', None, None, 'اسم')

# %%
SQLdf = pd.read_sql(query, conn)
SQLdf
# Out:
#              GroupID GroupArabicName GroupEnglishName WordType
# 0      أسماء الإشارة            None             None      اسم
# 1              أعلام            None             None      اسم
# 2              أماكن            None             None      اسم
# 3        إن وأخواتها            None             None      حرف
# 4              أنهار            None             None      اسم
# 5     الأسماء الخمسة            None             None      اسم
# 6   الأسماء الموصولة            None             None      اسم
# 7             الطعام            None             None      اسم
# 8               بحار            None             None      اسم
# 9     حروف الاستفتاح            None             None      حرف
# 10    حروف الاستفهام            None             None      حرف
# 11      حروف التفسير            None             None      حرف
# 12         حروف الجر            None             None      حرف
# 13        حروف الجزم            None             None      حرف
# 14        حروف الشرط            None             None      حرف
# 15        حروف العطف            None             None      حرف
# 16        حروف القسم            None             None      حرف
# 17        حروف النصب            None             None      حرف
# 18        حروف النفي            None             None      حرف
# 19       حروف الهجاء            None             None      حرف
# 20           حيوانات            None             None      اسم
# 21      كان وأخواتها            None             None      فعل
# 22           محافظات            None             None      اسم
# 23      معالم سياحية            None             None      اسم
# 24             ملابس            None             None      اسم
# 25           مناسبات            None             None      اسم
# 26      مناطق مشهورة            None             None      اسم
# 27            نباتات            None             None      اسم

# %%
#reading data from procedure
SQLdf = pd.read_sql("sp_groups", conn)
SQLdf
# Out:
#              GroupID GroupArabicName GroupEnglishName WordType
# 0      أسماء الإشارة            None             None      اسم
# 1              أعلام            None             None      اسم
# 2              أماكن            None             None      اسم
# 3        إن وأخواتها            None             None      حرف
# 4              أنهار            None             None      اسم
# 5     الأسماء الخمسة            None             None      اسم
# 6   الأسماء الموصولة            None             None      اسم
# 7             الطعام            None             None      اسم
# 8               بحار            None             None      اسم
# 9     حروف الاستفتاح            None             None      حرف
# 10    حروف الاستفهام            None             None      حرف
# 11      حروف التفسير            None             None      حرف
# 12         حروف الجر            None             None      حرف
# 13        حروف الجزم            None             None      حرف
# 14        حروف الشرط            None             None      حرف
# 15        حروف العطف            None             None      حرف
# 16        حروف القسم            None             None      حرف
# 17        حروف النصب            None             None      حرف
# 18        حروف النفي            None             None      حرف
# 19       حروف الهجاء            None             None      حرف
# 20           حيوانات            None             None      اسم
# 21      كان وأخواتها            None             None      فعل
# 22           محافظات            None             None      اسم
# 23      معالم سياحية            None             None      اسم
# 24             ملابس            None             None      اسم
# 25           مناسبات            None             None      اسم
# 26      مناطق مشهورة            None             None      اسم
# 27            نباتات            None             None      اسم

# %%
#reading data from view
SQLdf = pd.read_sql("select * from vwgroups", conn)
SQLdf
# Out:
#              GroupID GroupArabicName GroupEnglishName WordType
# 0      أسماء الإشارة            None             None      اسم
# 1              أعلام            None             None      اسم
# 2              أماكن            None             None      اسم
# 3        إن وأخواتها            None             None      حرف
# 4              أنهار            None             None      اسم
# 5     الأسماء الخمسة            None             None      اسم
# 6   الأسماء الموصولة            None             None      اسم
# 7             الطعام            None             None      اسم
# 8               بحار            None             None      اسم
# 9     حروف الاستفتاح            None             None      حرف
# 10    حروف الاستفهام            None             None      حرف
# 11      حروف التفسير            None             None      حرف
# 12         حروف الجر            None             None      حرف
# 13        حروف الجزم            None             None      حرف
# 14        حروف الشرط            None             None      حرف
# 15        حروف العطف            None             None      حرف
# 16        حروف القسم            None             None      حرف
# 17        حروف النصب            None             None      حرف
# 18        حروف النفي            None             None      حرف
# 19       حروف الهجاء            None             None      حرف
# 20           حيوانات            None             None      اسم
# 21      كان وأخواتها            None             None      فعل
# 22           محافظات            None             None      اسم
# 23      معالم سياحية            None             None      اسم
# 24             ملابس            None             None      اسم
# 25           مناسبات            None             None      اسم
# 26      مناطق مشهورة            None             None      اسم
# 27            نباتات            None             None      اسم

# %% [markdown]
# # Matplotlib Liberary Visualization Samples

# %%
groupeddf = SQLdf.groupby("WordType").count()
groupeddf
# Out:
#           GroupID  GroupArabicName  GroupEnglishName
# WordType
# اسم            15                0                 0
# حرف            12                0                 0
# فعل             1                0                 0

# %%
groupeddf.plot.bar()

# %%
groupeddf.plot.hist()

# %%
groupeddf.plot.box()
